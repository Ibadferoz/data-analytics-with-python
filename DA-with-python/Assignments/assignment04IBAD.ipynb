# %% [markdown]
# Q1 — Basic Dictionary Creation
# Create a dictionary called student with keys: name, age, course, city. Print each value.
# student = {
# "name": "",
# "age": ,
# "course": "",
# "city": ""
# }

# %%
student = {
    "name": "IBAD",
    "age": 21,
    "course": "DATA_ANALYSIS WITH PYHTON",
    "city": "KARACHI",
}

print(student["name"])
print(student["age"])
print(student["course"])
print(student["city"])
# Out:
# IBAD
# 21
# DATA_ANALYSIS WITH PYHTON
# KARACHI

# %% [markdown]
# Q2 — Adding & Updating Values
# car = {
# "brand": "Toyota",
# "model": "Corolla",
# "year": 2018
# }
# Add color='White', update year to 2022 and print dictionary.

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2018}

car["color"] = "White"

car["year"] = 2022

print(car)
# Out:
# {'brand': 'Toyota', 'model': 'Corolla', 'year': 2022, 'color': 'White'}

# %% [markdown]
# Q3 — Loop Through Dictionary
# person = {
# "name": "Ali",
# "age": 25,
# "city": "Karachi"
# }
# Print keys and values using loop

# %%
person = {"name": "Ali", "age": 25, "city": "Karachi"}

for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# name: Ali
# age: 25
# city: Karachi

# %% [markdown]
# Q4 — Count Frequency of Numbers
# numbers = [1,2,2,3,3,3,4,4,4,4]
# Create frequency dictionary.

# %%
numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

freq = {}
for num in numbers:
    freq[num] = freq.get(num, 0) + 1
print(freq)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %% [markdown]
# Q5 — Word Counter
# Take sentence input and count word frequency.

# %%
sentence = input("Enter a sentence: ")

words = sentence.lower().split()
word_counts = {}
for word in words:
    word_counts[word] = word_counts.get(word, 0) + 1

print(word_counts)
# Out:
# {'apple': 2, 'banana': 1, 'orange': 2}

# %% [markdown]
# Q6 — Student Marks & Average
# marks = {"Math":80, "English":70, "Physics":90}
# Calculate total and average.

# %%
marks = {"Math": 80, "English": 70, "Physics": 90}

total = sum(marks.values())
average = total / len(marks)

print(f"Total Marks: {total}")
print(f"Average Marks: {average}")
# Out:
# Total Marks: 240
# Average Marks: 80.0

# %% [markdown]
# Q7 — Highest Scoring Student
# students = {
# "Ali":85,
# "Sara":92,
# "Ahmed":78,
# "Zara":95
# }
# Find highest scoring student.

# %%
students = {"Ali": 85, "Sara": 92, "Ahmed": 78, "Zara": 95}

highest_student = max(students, key=students.get)
highest_score = students[highest_student]

print(f"Top Student: {highest_student} with {highest_score} marks")
# Out:
# Top Student: Zara with 95 marks

# %% [markdown]
# Q8 — Merge Dictionaries
# dict1 = {"a":1,"b":2}
# dict2 = {"c":3,"d":4}
# Merge and print result.

# %%
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}

merged_dict = dict1 | dict2

print(merged_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# Q9 — Mini Project: Contact Book
# Add 3 contacts, search by name, print phone or Contact not found.

# %%
contacts = {}

contacts["usman"] = "03001234567"
contacts["iqra"] = "03119876543"
contacts["hashim"] = "03215554433"

name_to_search = input("Enter contact name to search: ")

if name_to_search in contacts:
    print(f"Phone Number: {contacts[name_to_search]}")
else:
    print("Contact not found")
# Out:
# Phone Number: 03119876543
