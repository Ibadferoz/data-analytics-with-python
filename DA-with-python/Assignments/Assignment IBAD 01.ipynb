# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print ("Name: Ibad\nFather'sName:Muhammad Feroz\nDate of Birth: 12/10/2005")
# Out:
# Name: Ibad
# Father'sName:Muhammad Feroz
# Date of Birth: 12/10/2005

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Ibad"
age = 21 
profession = "bussinessman" 
hobby = "playing cricket"
print (f"My name is {name}. I am {age} years old. I am a {profession}. My hobby is {hobby}.")
""
# Out:
# My name is Ibad. I am 21 years old. I am a bussinessman. My hobby is playing cricket.
# ''

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a,b = 30,60
#arirthmetic operations
print (a+b)
print (a*b)
#comparison operations
print (a==b)
print (a<b)
#logical operations
print (a<20 and b<70)
print (a==40 or b>=60)
print (not b>=60)
#bitwise operations
print (a&b)
print (a|b)
print (a^b)
# Out:
# 90
# 1800
# False
# True
# False
# True
# False
# 28
# 62
# 34

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = 95
islamiat = 78
maths = 85
total_marks = 300
obtained_marks = english + islamiat + maths
percentage = (obtained_marks / total_marks) * 100
print(f"Obtained Marks: {obtained_marks}")
print(f"Percentage: {percentage:.2f}%")
# Out:
# Obtained Marks: 258
# Percentage: 86.00%

# %% [markdown]
# 5. Take the values of two variables `a` and `b`, then swap their values without using a third variable and print the result before and after swapping

# %%
A = 40
B = 60
print("Before swapping:")
print("A =", A)
print("B =", B) 
A,B = B,A 
print("\nAfter swapping:")
print("A =", A)
print("B =", B)
# Out:
# Before swapping:
# A = 40
# B = 60
#
# After swapping:
# A = 60
# B = 40

# %% [markdown]
# 6. Take the radius of a circle from a variable and calculate its Area and Circumference (use `pi = 3.14159`)

# %%
pi = 3.14159
radius = 9
area = pi * radius**2
circumference = 2 * pi * radius
print (radius)
print (area)
print (circumference)
# Out:
# 9
# 254.46878999999998
# 56.54862

# %% [markdown]
# 7. Take the price of an item and a discount percentage in variables, then calculate and print the discount amount and the final price after discount

# %%
scarfprice = 650
discountpercentage = 10 
discountamount = (scarfprice * discountpercentage) / 100
finalprice = scarfprice - discountamount
print (finalprice)
print (discountamount)
# Out:
# 585.0
# 65.0
